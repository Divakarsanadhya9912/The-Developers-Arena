# %%
import pandas as pd
import sys
import os

sys.path.append(os.getcwd())

from cleaning import load_data, basic_inspection
from visualization import (
    temperature_trend,
    rainfall_distribution,
    seasonal_temperature,
    extreme_weather
)

# %%
df = load_data("../datasets/weather_data.csv")

basic_inspection(df)
# Out:
# Shape: (731, 11)
#
# Columns:
#  Index(['Date', 'Min_Temperature', 'Max_Temperature', 'Avg_Temperature',
#        'Rainfall_mm', 'Humidity_%', 'Wind_Speed_kmph', 'Extreme_Event', 'year',
#        'month', 'day'],
#       dtype='str')
#
# Missing Values:
#  Date               0
# Min_Temperature    0
# Max_Temperature    0
# Avg_Temperature    0
# Rainfall_mm        0
# Humidity_%         0
# Wind_Speed_kmph    0
# Extreme_Event      0
# year               0
# month              0
# day                0
# dtype: int64
#
# Data Types:
#  Date               datetime64[us]
# Min_Temperature           float64
# Max_Temperature           float64
# Avg_Temperature           float64
# Rainfall_mm               float64
# Humidity_%                float64
# Wind_Speed_kmph           float64
# Extreme_Event               int64
# year                        int32
# month                       int32
# day                         int32
# dtype: object

# %%
temperature_trend(df)

rainfall_distribution(df)

seasonal_temperature(df)

extreme_weather(df)
