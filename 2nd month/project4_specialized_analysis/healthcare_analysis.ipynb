# %%
import pandas as pd
import sys
import os

sys.path.append(os.getcwd())

from cleaning import load_data, clean_data, basic_inspection
from visualization import (
    age_distribution,
    disease_distribution,
    bmi_vs_age,
    glucose_distribution
)

# %%
df = load_data("../datasets/healthcare_data.csv")

df = clean_data(df)

basic_inspection(df)
# Out:
# Shape: (1000, 12)
#
# Columns:
#  Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='str')
#
# Missing Values:
#  id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64
#
# Data Types:
#  id                     int64
# gender                   str
# age                    int64
# hypertension           int64
# heart_disease          int64
# ever_married             str
# work_type                str
# Residence_type           str
# avg_glucose_level    float64
# bmi                  float64
# smoking_status           str
# stroke                 int64
# dtype: object

# %%
age_distribution(df)

disease_distribution(df)

bmi_vs_age(df)

glucose_distribution(df)
